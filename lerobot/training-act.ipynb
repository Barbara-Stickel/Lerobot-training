# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Currently logged in as: bss2137 (barbara-adrien-nyc) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Add Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Login into Hugging Face Hub
# Before starting the training, login into the Hugging Face hub

# %%
# !huggingface-cli login

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %% [markdown]
# ### To resume a training

# %%
# !lerobot-train \
  --config_path=/content/drive/MyDrive/outputs/train/act_record_chess_1/checkpoints/last/pretrained_model/train_config.json \
  --resume=true
# Out:
# INFO 2026-01-03 22:17:31 ot_train.py:187 {'batch_size': 4,
#  'checkpoint_path': '/content/drive/MyDrive/outputs/train/act_record_chess_1/checkpoints/last',
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'barbarastickel/record-chess-1',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'act_record_chess_1',
#  'log_freq': 100,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': '/content/drive/MyDrive/outputs/train/act_record_chess_1',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {'observation.images.front': {'shape': [3,
#                                                                       1080,
#                                                                       1920],
#                                                             'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.state': {'shape': [6],
#                                                      'type': <FeatureType.STATE: 'STATE'>}},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {'action': {'shape': [6],
#                                            'type': <FeatureType.ACTION: 'ACTION'>}},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': '/content/drive/MyDrive/outputs/train/act_record_chess_1/checkpoints/last/pretrained_model',
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': 0,
#             'repo_id': 'barbarastickel/policy-record-chess-1',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rabc_epsilon': 1e-06,
#  'rabc_head_mode': 'sparse',
#  'rabc_kappa': 0.01,
#  'rabc_progress_path': None,
#  'rename_map': {},
#  'resume': True,
#  'save_checkpoint': True,
#  'save_freq': 500,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 100000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'use_rabc': False,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': 'b9kdx4cw'}}
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2026-01-03 22:17:33 db_utils.py:102 Logs will be synced with wandb.
# INFO 2026-01-03 22:17:33 db_utils.py:103 Track this run --> https://wandb.ai/barbara-adrien-nyc/lerobot/runs/b9kdx4cw
# INFO 2026-01-03 22:17:33 ot_train.py:207 Creating dataset
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# meta/episodes/chunk-000/file-004.parquet:   0% 0.00/49.3k [00:00<?, ?B/s]
#
# meta/episodes/chunk-000/file-000.parquet:   0% 0.00/49.2k [00:00<?, ?B/s]
#
#
# meta/episodes/chunk-000/file-003.parquet:   0% 0.00/49.2k [00:00<?, ?B/s]
#
#
#
# meta/episodes/chunk-000/file-007.parquet:   0% 0.00/49.1k [00:00<?, ?B/s]
#
#
#
#
# meta/episodes/chunk-000/file-005.parquet:   0% 0.00/48.7k [00:00<?, ?B/s]
#
#
#
#
#
# meta/episodes/chunk-000/file-006.parquet:   0% 0.00/49.4k [00:00<?, ?B/s]
#
#
#
#
#
#
# meta/episodes/chunk-000/file-002.parquet:   0% 0.00/49.2k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# meta/episodes/chunk-000/file-001.parquet:   0% 0.00/49.1k [00:00<?, ?B/s]
#
#
#
#
# meta/episodes/chunk-000/file-005.parquet: 100% 48.7k/48.7k [00:00<00:00, 81.1kB/s]
#
# meta/episodes/chunk-000/file-000.parquet: 100% 49.2k/49.2k [00:00<00:00, 80.4kB/s]
# meta/episodes/chunk-000/file-005.parquet: 100% 48.7k/48.7k [00:00<00:00, 80.7kB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:10,  1.18it/s]
# meta/episodes/chunk-000/file-004.parquet: 100% 49.3k/49.3k [00:00<00:00, 77.8kB/s]
#
#
#
#
#
#
#
#
# meta/episodes/chunk-000/file-001.parquet: 100% 49.1k/49.1k [00:00<00:00, 87.1kB/s]
#
#
#
#
#
#
# meta/episodes/chunk-000/file-001.parquet: 100% 49.1k/49.1k [00:00<00:00, 85.4kB/s]
# meta/episodes/chunk-000/file-002.parquet: 100% 49.2k/49.2k [00:00<00:00, 79.4kB/s]
#
#
#
# meta/episodes/chunk-000/file-003.parquet: 100% 49.2k/49.2k [00:00<00:00, 72.1kB/s]
#
#
#
#
# meta/episodes/chunk-000/file-007.parquet: 100% 49.1k/49.1k [00:00<00:00, 69.9kB/s]
#
# meta/episodes/chunk-000/file-008.parquet:   0% 0.00/49.2k [00:00<?, ?B/s]
#
#
#
#
#
# meta/episodes/chunk-000/file-006.parquet: 100% 49.4k/49.4k [00:00<00:00, 61.4kB/s]
# Fetching 13 files:  54% 7/13 [00:01<00:00,  8.43it/s]
#
# meta/episodes/chunk-000/file-009.parquet:   0% 0.00/48.9k [00:00<?, ?B/s]
#
#
# meta/tasks.parquet:   0% 0.00/2.26k [00:00<?, ?B/s]
#
#
#
# info.json: 2.60kB [00:00, 6.59MB/s]
#
#
#
#
# stats.json: 9.90kB [00:00, 25.5MB/s]
#
# meta/episodes/chunk-000/file-008.parquet: 100% 49.2k/49.2k [00:00<00:00, 159kB/s]
# Fetching 13 files:  69% 9/13 [00:01<00:00,  7.86it/s]
#
# meta/episodes/chunk-000/file-009.parquet: 100% 48.9k/48.9k [00:00<00:00, 155kB/s]
#
#
#
# meta/tasks.parquet: 100% 2.26k/2.26k [00:00<00:00, 6.94kB/s]
# Fetching 13 files: 100% 13/13 [00:01<00:00,  9.22it/s]
# Fetching 41 files:   0% 0/41 [00:00<?, ?it/s]
# data/chunk-000/file-000.parquet:   0% 0.00/143k [00:00<?, ?B/s]
#
# data/chunk-000/file-002.parquet:   0% 0.00/138k [00:00<?, ?B/s]
#
#
# data/chunk-000/file-003.parquet:   0% 0.00/135k [00:00<?, ?B/s]
#
#
#
# data/chunk-000/file-001.parquet:   0% 0.00/143k [00:00<?, ?B/s]
#
#
#
#
# README.md: 3.09kB [00:00, 1.21MB/s]
#
#
#
#
#
# .DS_Store: 100% 8.20k/8.20k [00:00<00:00, 29.1MB/s]
#
#
#
#
#
# .DS_Store: 100% 6.15k/6.15k [00:00<00:00, 22.6MB/s]
# Fetching 41 files:   2% 1/41 [00:00<00:10,  3.73it/s]
#
#
#
#
# .gitattributes: 2.46kB [00:00, 10.2MB/s]
#
#
#
#
# data/chunk-000/file-001.parquet: 100% 143k/143k [00:00<00:00, 686kB/s]
#
#
#
# data/chunk-000/file-003.parquet: 100% 135k/135k [00:00<00:00, 607kB/s]
#
# data/chunk-000/file-000.parquet: 100% 143k/143k [00:00<00:00, 554kB/s]
#
# Fetching 41 files:  12% 5/41 [00:00<00:02, 12.62it/s]
#
#
# data/chunk-000/file-005.parquet:   0% 0.00/144k [00:00<?, ?B/s]
#
#
#
# data/chunk-000/file-006.parquet:   0% 0.00/148k [00:00<?, ?B/s]
#
# data/chunk-000/file-002.parquet: 100% 138k/138k [00:00<00:00, 451kB/s]
#
#
# data/chunk-000/file-007.parquet:   0% 0.00/149k [00:00<?, ?B/s]
#
#
#
#
# data/chunk-000/file-008.parquet:   0% 0.00/145k [00:00<?, ?B/s]
#
#
# data/chunk-000/file-005.parquet: 100% 144k/144k [00:00<00:00, 701kB/s]
#
# data/chunk-000/file-004.parquet: 100% 140k/140k [00:00<00:00, 566kB/s]
# Fetching 41 files:  22% 9/41 [00:00<00:02, 14.17it/s]
#
#
#
# data/chunk-000/file-006.parquet: 100% 148k/148k [00:00<00:00, 538kB/s]
#
# .DS_Store: 100% 6.15k/6.15k [00:00<00:00, 11.8MB/s]
#
# data/chunk-000/file-009.parquet:   0% 0.00/135k [00:00<?, ?B/s]
#
#
# .DS_Store: 100% 6.15k/6.15k [00:00<00:00, 21.2MB/s]
#
#
# data/chunk-000/file-007.parquet: 100% 149k/149k [00:00<00:00, 689kB/s]
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/204M [00:00<?, ?B/s]
#
#
#
#
# data/chunk-000/file-008.parquet: 100% 145k/145k [00:00<00:00, 527kB/s]
#
#
#
# Fetching 41 files:  32% 13/41 [00:00<00:01, 16.20it/s]
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/47.6M [00:00<?, ?B/s]
#
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/200M [00:00<?, ?B/s]
# data/chunk-000/file-009.parquet: 100% 135k/135k [00:00<00:00, 489kB/s]
# Fetching 41 files:  37% 15/41 [00:01<00:01, 15.49it/s]
# videos/observation.images.front/chunk-00(…):   0% 0.00/45.1M [00:00<?, ?B/s]
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/183M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/183M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/181M [00:00<?, ?B/s]
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 47.6M/47.6M [00:00<00:00, 101MB/s]
#
#
# videos/observation.images.front/chunk-00(…):   2% 3.16M/204M [00:00<00:37, 5.38MB/s]
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/170M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  27% 48.6M/183M [00:02<00:07, 18.3MB/s]
#
# videos/observation.images.front/chunk-00(…):  34% 70.3M/204M [00:03<00:06, 21.6MB/s]
# videos/observation.images.front/chunk-00(…): 100% 45.1M/45.1M [00:03<00:00, 13.5MB/s]
#
#
# videos/observation.images.front/chunk-00(…):  67% 137M/204M [00:03<00:01, 45.3MB/s]
# videos/observation.images.front/chunk-00(…):   0% 0.00/162M [00:00<?, ?B/s]
#
#
# videos/observation.images.front/chunk-00(…):  24% 43.4M/177M [00:03<00:11, 11.3MB/s]
#
#
#
# videos/observation.images.front/chunk-00(…):  21% 35.3M/170M [00:03<00:12, 10.5MB/s]
#
#
#
#
# videos/observation.images.front/chunk-00(…):  34% 67.1M/200M [00:04<00:08, 16.2MB/s]
#
#
#
#
# videos/observation.images.front/chunk-00(…):  67% 134M/200M [00:04<00:01, 35.4MB/s]
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  27% 49.0M/183M [00:04<00:11, 11.2MB/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  63% 116M/183M [00:04<00:02, 26.4MB/s]
#
# videos/observation.images.front/chunk-00(…): 100% 204M/204M [00:05<00:00, 38.8MB/s]
# Fetching 41 files:  73% 30/41 [00:06<00:02,  3.82it/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 183M/183M [00:05<00:00, 35.9MB/s]
#
#
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  26% 47.0M/181M [00:05<00:14, 9.16MB/s]
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/163M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/161M [00:00<?, ?B/s]
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 200M/200M [00:05<00:00, 34.6MB/s]
#
#
#
# videos/observation.images.front/chunk-00(…):  62% 110M/177M [00:06<00:03, 19.9MB/s]
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  63% 116M/183M [00:06<00:03, 20.6MB/s]
#
#
# videos/observation.images.front/chunk-00(…): 100% 177M/177M [00:06<00:00, 27.0MB/s]
# Fetching 41 files:  78% 32/41 [00:07<00:02,  3.21it/s]
#
#
#
# videos/observation.images.front/chunk-00(…):  60% 102M/170M [00:06<00:03, 17.5MB/s]
#
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 183M/183M [00:06<00:00, 26.5MB/s]
# Fetching 41 files:  88% 36/41 [00:08<00:01,  3.77it/s]
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 170M/170M [00:06<00:00, 31.8MB/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 170M/170M [00:06<00:00, 25.2MB/s]
#
#
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  63% 114M/181M [00:07<00:03, 17.2MB/s]
# videos/observation.images.front/chunk-00(…):  17% 28.1M/162M [00:04<00:19, 6.79MB/s]
#
# videos/observation.images.front/chunk-00(…):  18% 29.0M/163M [00:02<00:12, 11.0MB/s]
#
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 181M/181M [00:07<00:00, 23.0MB/s]
# Fetching 41 files:  90% 37/41 [00:09<00:01,  2.95it/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  58% 94.4M/161M [00:03<00:02, 29.9MB/s]
# videos/observation.images.front/chunk-00(…):  59% 95.2M/162M [00:05<00:03, 21.5MB/s]
# videos/observation.images.front/chunk-00(…): 100% 162M/162M [00:05<00:00, 40.4MB/s]
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100% 162M/162M [00:05<00:00, 28.9MB/s]
# videos/observation.images.front/chunk-00(…): 100% 161M/161M [00:03<00:00, 42.3MB/s]
# Fetching 41 files:  95% 39/41 [00:10<00:00,  2.60it/s]
#
# videos/observation.images.front/chunk-00(…):  59% 96.0M/163M [00:04<00:02, 25.2MB/s]
#
# videos/observation.images.front/chunk-00(…): 100% 163M/163M [00:04<00:00, 37.2MB/s]
# Fetching 41 files: 100% 41/41 [00:10<00:00,  3.78it/s]
# INFO 2026-01-03 22:17:46 ot_train.py:226 Creating policy
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 61.2MB/s]
# Loading weights from local directory
# INFO 2026-01-03 22:17:49 ot_train.py:275 Creating optimizer and scheduler
# INFO 2026-01-03 22:17:58 ot_train.py:310 Output dir: /content/drive/MyDrive/outputs/train/act_record_chess_1
# INFO 2026-01-03 22:17:58 ot_train.py:317 cfg.steps=100000 (100K)
# INFO 2026-01-03 22:17:58 ot_train.py:318 dataset.num_frames=28996 (29K)
# INFO 2026-01-03 22:17:58 ot_train.py:319 dataset.num_episodes=50
# INFO 2026-01-03 22:17:58 ot_train.py:322 Effective batch size: 4 x 1 = 4
# INFO 2026-01-03 22:17:58 ot_train.py:323 num_learnable_params=51597190 (52M)
# INFO 2026-01-03 22:17:58 ot_train.py:324 num_total_params=51597190 (52M)
# /usr/local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO 2026-01-03 22:17:58 ot_train.py:380 Start offline training on a fixed dataset, with effective batch size: 4
# INFO 2026-01-03 22:19:56 ot_train.py:410 step:4K smpl:16K ep:28 epch:0.57 loss:0.790 grdn:49.284 lr:1.0e-05 updt_s:1.127 data_s:0.047
# INFO 2026-01-03 22:21:43 ot_train.py:410 step:4K smpl:17K ep:29 epch:0.58 loss:0.778 grdn:49.280 lr:1.0e-05 updt_s:1.057 data_s:0.011
# INFO 2026-01-03 22:23:30 ot_train.py:410 step:4K smpl:17K ep:30 epch:0.59 loss:0.746 grdn:47.373 lr:1.0e-05 updt_s:1.057 data_s:0.011
# INFO 2026-01-03 22:25:17 ot_train.py:410 step:4K smpl:18K ep:30 epch:0.61 loss:0.756 grdn:48.834 lr:1.0e-05 updt_s:1.061 data_s:0.011
# INFO 2026-01-03 22:27:03 ot_train.py:410 step:4K smpl:18K ep:31 epch:0.62 loss:0.704 grdn:45.021 lr:1.0e-05 updt_s:1.054 data_s:0.011
# INFO 2026-01-03 22:27:03 ot_train.py:430 Checkpoint policy after step 4500

# %% [markdown]
# ### To start a new training

# %%
# !lerobot-train \
  --dataset.repo_id="barbarastickel/record-test" \
  --policy.type=act \
  --output_dir=/content/drive/MyDrive/outputs/train/act_so101_test \
  --job_name=act_so101_test \
  --policy.device=cuda \
  --wandb.enable=true \
  --policy.repo_id="barbarastickel/my_policy" \
  --batch_size=4 \
  --log_freq=100 \
  --save_frequency=500

# %% [markdown]
# ## Upload to the policy
# Once the training is done, upload the policy to hugging face

# %%
# !huggingface-cli upload ${HF_USER}/il_sim_test0 \
  /content/lerobot/outputs/train/il_sim_test0/checkpoints/last/pretrained_model
